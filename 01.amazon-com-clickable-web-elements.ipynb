# %% [markdown]
# <a href="https://colab.research.google.com/github/temiyemi/visual-web-agent/blob/main/clickable_web_elements.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip -u -d data amazon-datasets.v4.yolov5pytorch.zip
# %ls data/
# Out:
# Archive:  amazon-datasets.v4.yolov5pytorch.zip
#  extracting: data/README.dataset.txt
#  extracting: data/README.roboflow.txt
#  extracting: data/data.yaml
#    creating: data/test/
#    creating: data/test/images/
#  extracting: data/test/images/11_png.rf.089f91284b4f91185603543c67d9a27e.jpg
#  extracting: data/test/images/1_png.rf.03d914ff5a7af7fe261a804110ac53ec.jpg
#  extracting: data/test/images/Screenshot-2024-05-01-at-1-20-44-AM_png.rf.4f874e581b76fcb77e0ad84237660bdd.jpg
#  extracting: data/test/images/Screenshot-2024-05-02-at-2-52-47-PM_png.rf.cf41c479303de2da5acf359bc7adf304.jpg
#  extracting: data/test/images/Screenshot-2024-05-02-at-2-55-13-PM_png.rf.d4f4362da38bfe9b0d2857baf64cdc26.jpg
#  extracting: data/test/images/Screenshot-2024-05-02-at-3-01-28-PM_png.rf.91364eb927056dcd9dc740e7644b61f2.jpg
#  extracting: data/test/images/Screenshot_1_png.rf.818b08d19ea98f948becfb984dccbdb8.jpg
#  extracting: data/test/images/Screenshot_1_png.rf.97d44e4f9180be9896f9e9165485cb2b.jpg
# ...

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone yolov5 repo
# %cd yolov5
# %pip install -qr requirements.txt comet_ml  # install requirement, then install comet

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-306-gb599ae42 Python-3.10.12 torch-2.2.1+cu121 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 29.0/107.7 GB disk)

# %%
# !export COMET_API_KEY='COMET_API_KEY'

# %%
import comet_ml

comet_ml.init()

# %%
# !python train.py --img 640 --epochs 3 --data ../datasets.yaml --weights yolov5s.pt  # 3. train
# Out:
# 2024-05-03 10:53:38.170829: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-03 10:53:38.170936: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-03 10:53:38.178234: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
